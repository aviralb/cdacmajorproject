# %%
import pandas as pd

import pyarrow
import fastparquet

# %%
a = pd.read_parquet('1 (1).parquet')
b = pd.read_parquet('1 (2).parquet')
c = pd.read_parquet('1 (3).parquet')
d = pd.read_parquet('1 (4).parquet')
e = pd.read_parquet('1 (5).parquet')
f = pd.read_parquet('1 (6).parquet')
g = pd.read_parquet('1 (7).parquet')
h = pd.read_parquet('1 (8).parquet')
i = pd.read_parquet('1 (9).parquet')
j = pd.read_parquet('1 (10).parquet')
k = pd.read_parquet('1 (11).parquet')
l = pd.read_parquet('1 (12).parquet')
m = pd.read_parquet('1 (13).parquet')
n = pd.read_parquet('1 (14).parquet')
o = pd.read_parquet('1 (15).parquet')
p = pd.read_parquet('1 (16).parquet')
q = pd.read_parquet('1 (17).parquet')
r = pd.read_parquet('1 (18).parquet')
s = pd.read_parquet('1 (19).parquet')
t = pd.read_parquet('1 (20).parquet')
u = pd.read_parquet('1 (21).parquet')
v = pd.read_parquet('1 (22).parquet')
w = pd.read_parquet('1 (23).parquet')
x = pd.read_parquet('1 (24).parquet')
y = pd.read_parquet('1 (25).parquet')
z = pd.read_parquet('1 (26).parquet')
aa = pd.read_parquet('1 (27).parquet')
ab = pd.read_parquet('1 (28).parquet')
ac = pd.read_parquet('1 (29).parquet')
ad = pd.read_parquet('1 (30).parquet')
ae = pd.read_parquet('1 (31).parquet')
af = pd.read_parquet('1 (32).parquet')
ag = pd.read_parquet('1 (33).parquet')
ah = pd.read_parquet('1 (34).parquet')
ai = pd.read_parquet('1 (35).parquet')
aj = pd.read_parquet('1 (36).parquet')
ak = pd.read_parquet('1 (37).parquet')
al = pd.read_parquet('1 (38).parquet')
am = pd.read_parquet('1 (39).parquet')
an = pd.read_parquet('1 (40).parquet')
ao = pd.read_parquet('1 (41).parquet')
ap = pd.read_parquet('1 (42).parquet')
aq = pd.read_parquet('1 (43).parquet')

a1=pd.read_parquet('1 (44).parquet')
a2=pd.read_parquet('1 (45).parquet')
a3=pd.read_parquet('1 (46).parquet')
a4=pd.read_parquet('1 (47).parquet')
a5=pd.read_parquet('1 (48).parquet')
a6=pd.read_parquet('1 (49).parquet')
a7=pd.read_parquet('1 (50).parquet')
a8=pd.read_parquet('1 (51).parquet')
a9=pd.read_parquet('1 (52).parquet')
a10=pd.read_parquet('1 (53).parquet')
a11=pd.read_parquet('1 (54).parquet')
a12=pd.read_parquet('1 (55).parquet')
a13=pd.read_parquet('1 (56).parquet')
a14=pd.read_parquet('1 (57).parquet')
a15=pd.read_parquet('1 (58).parquet')
a16=pd.read_parquet('1 (59).parquet')
a17=pd.read_parquet('1 (60).parquet')
a18=pd.read_parquet('1 (61).parquet')
a19=pd.read_parquet('1 (62).parquet')
a20=pd.read_parquet('1 (63).parquet')

a21=pd.read_parquet('1 (64).parquet')
a22=pd.read_parquet('1 (65).parquet')
a23=pd.read_parquet('1 (66).parquet')
a24=pd.read_parquet('1 (67).parquet')
a25=pd.read_parquet('1 (68).parquet')
a26=pd.read_parquet('1 (69).parquet')
a27=pd.read_parquet('1 (70).parquet')
a28=pd.read_parquet('1 (71).parquet')
a29=pd.read_parquet('1 (72).parquet')
a30=pd.read_parquet('1 (73).parquet')
a31=pd.read_parquet('1 (74).parquet')
a32=pd.read_parquet('1 (75).parquet')
a33=pd.read_parquet('1 (76).parquet')
a34=pd.read_parquet('1 (77).parquet')
a35=pd.read_parquet('1 (78).parquet')
a36=pd.read_parquet('1 (79).parquet')
a37=pd.read_parquet('1 (80).parquet')
a38=pd.read_parquet('1 (81).parquet')
a39=pd.read_parquet('1 (82).parquet')
a40=pd.read_parquet('1 (83).parquet')
a41=pd.read_parquet('1 (84).parquet')
a42=pd.read_parquet('1 (85).parquet')
a43=pd.read_parquet('1 (86).parquet')
a44=pd.read_parquet('1 (87).parquet')
a45=pd.read_parquet('1 (88).parquet')
a46=pd.read_parquet('1 (89).parquet')
a47=pd.read_parquet('1 (90).parquet')
a48=pd.read_parquet('1 (91).parquet')
a49=pd.read_parquet('1 (92).parquet')
a50=pd.read_parquet('1 (93).parquet')
a51=pd.read_parquet('1 (94).parquet')
a52=pd.read_parquet('1 (95).parquet')
a53=pd.read_parquet('1 (96).parquet')
a54=pd.read_parquet('1 (97).parquet')
a55=pd.read_parquet('1 (98).parquet')

a56=pd.read_parquet('1 (99).parquet')
a57=pd.read_parquet('1 (100).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')
a55=pd.read_parquet('1 (98).parquet')

a56=pd.read_parquet('1 (99).parquet')
a57=pd.read_parquet('1 (100).parquet')
a58=pd.read_parquet('1 (101).parquet')
a59=pd.read_parquet('1 (102).parquet')
a60=pd.read_parquet('1 (103).parquet')
a61=pd.read_parquet('1 (104).parquet')
a62=pd.read_parquet('1 (105).parquet')
a63=pd.read_parquet('1 (106).parquet')
a64=pd.read_parquet('1 (107).parquet')
a65=pd.read_parquet('1 (108).parquet')
a66=pd.read_parquet('1 (109).parquet')
a67=pd.read_parquet('1 (110).parquet')
a68=pd.read_parquet('1 (111).parquet')
a69=pd.read_parquet('1 (112).parquet')
a70=pd.read_parquet('1 (113).parquet')
a71=pd.read_parquet('1 (114).parquet')
a72=pd.read_parquet('1 (115).parquet')
a73=pd.read_parquet('1 (116).parquet')
a74=pd.read_parquet('1 (117).parquet')
a75=pd.read_parquet('1 (118).parquet')
a76=pd.read_parquet('1 (119).parquet')
a77=pd.read_parquet('1 (120).parquet')
a78=pd.read_parquet('1 (121).parquet')
a79=pd.read_parquet('1 (122).parquet')
a80=pd.read_parquet('1 (123).parquet')
a81=pd.read_parquet('1 (124).parquet')
a82=pd.read_parquet('1 (125).parquet')
a83=pd.read_parquet('1 (126).parquet')
a84=pd.read_parquet('1 (127).parquet')
a85=pd.read_parquet('1 (128).parquet')
a86=pd.read_parquet('1 (129).parquet')
a87=pd.read_parquet('1 (130).parquet')
a88=pd.read_parquet('1 (131).parquet')
a89=pd.read_parquet('1 (132).parquet')
a90=pd.read_parquet('1 (133).parquet')
a91=pd.read_parquet('1 (134).parquet')
a92=pd.read_parquet('1 (135).parquet')
a93=pd.read_parquet('1 (136).parquet')
a94=pd.read_parquet('1 (137).parquet')
a95=pd.read_parquet('1 (138).parquet')
a96=pd.read_parquet('1 (139).parquet')
a97=pd.read_parquet('1 (140).parquet')
a98=pd.read_parquet('1 (141).parquet')
a99=pd.read_parquet('1 (142).parquet')
a100=pd.read_parquet('1 (143).parquet')


a101=pd.read_parquet('1 (144).parquet')
a102=pd.read_parquet('1 (145).parquet')
a103=pd.read_parquet('1 (146).parquet')
a104=pd.read_parquet('1 (147).parquet')
a105=pd.read_parquet('1 (148).parquet')
a106=pd.read_parquet('1 (149).parquet')
a107=pd.read_parquet('1 (150).parquet')
a108=pd.read_parquet('1 (151).parquet')
a109=pd.read_parquet('1 (152).parquet')
a110=pd.read_parquet('1 (153).parquet')
a111=pd.read_parquet('1 (154).parquet')
a112=pd.read_parquet('1 (155).parquet')
a113=pd.read_parquet('1 (156).parquet')
a114=pd.read_parquet('1 (157).parquet')
a115=pd.read_parquet('1 (158).parquet')
a116=pd.read_parquet('1 (159).parquet')
a117=pd.read_parquet('1 (160).parquet')
a118=pd.read_parquet('1 (161).parquet')
a119=pd.read_parquet('1 (162).parquet')
a120=pd.read_parquet('1 (163).parquet')
a121=pd.read_parquet('1 (164).parquet')
a122=pd.read_parquet('1 (165).parquet')
a123=pd.read_parquet('1 (166).parquet')
a124=pd.read_parquet('1 (167).parquet')
a125=pd.read_parquet('1 (168).parquet')
a126=pd.read_parquet('1 (169).parquet')
a127=pd.read_parquet('1 (170).parquet')
a128=pd.read_parquet('1 (171).parquet')
a129=pd.read_parquet('1 (172).parquet')
a130=pd.read_parquet('1 (173).parquet')


a131=pd.read_parquet('1 (174).parquet')
a132=pd.read_parquet('1 (175).parquet')
a134=pd.read_parquet('1 (176).parquet')
a135=pd.read_parquet('1 (177).parquet')
a136=pd.read_parquet('1 (178).parquet')
a137=pd.read_parquet('1 (179).parquet')
a138=pd.read_parquet('1 (180).parquet')
a139=pd.read_parquet('1 (181).parquet')
a140=pd.read_parquet('1 (182).parquet')
a141=pd.read_parquet('1 (183).parquet')
a142=pd.read_parquet('1 (184).parquet')
a143=pd.read_parquet('1 (185).parquet')
a144=pd.read_parquet('1 (186).parquet')
a145=pd.read_parquet('1 (187).parquet')
a146=pd.read_parquet('1 (188).parquet')
a147=pd.read_parquet('1 (189).parquet')
a148=pd.read_parquet('1 (190).parquet')
a149=pd.read_parquet('1 (191).parquet')
a150=pd.read_parquet('1 (192).parquet')
a151=pd.read_parquet('1 (193).parquet')
a152=pd.read_parquet('1 (194).parquet')
a153=pd.read_parquet('1 (195).parquet')
a154=pd.read_parquet('1 (196).parquet')
a155=pd.read_parquet('1 (197).parquet')
a156=pd.read_parquet('1 (198).parquet')
a157=pd.read_parquet('1 (199).parquet')
a158=pd.read_parquet('1 (200).parquet')

# %%
a.to_csv('1.csv')
b.to_csv('2.csv')
c.to_csv('3.csv')
d.to_csv('4.csv')
e.to_csv('5.csv')
f.to_csv('6.csv')
g.to_csv('7.csv')
h.to_csv('8.csv')
i.to_csv('9.csv')
j.to_csv('10.csv')
k.to_csv('11.csv')
l.to_csv('12.csv')
m.to_csv('13.csv')
n.to_csv('14.csv')
o.to_csv('15.csv')
p.to_csv('16.csv')
q.to_csv('17.csv')
r.to_csv('18.csv')
s.to_csv('19.csv')
t.to_csv('20.csv')
u.to_csv('21.csv')
v.to_csv('22.csv')
w.to_csv('23.csv')
x.to_csv('24.csv')
y.to_csv('25.csv')
z.to_csv('26.csv')
aa.to_csv('27.csv')
ab.to_csv('28.csv')
ac.to_csv('29.csv')
ad.to_csv('30.csv')
ae.to_csv('31.csv')
af.to_csv('32.csv')
ag.to_csv('33.csv')
ah.to_csv('34.csv')
ai.to_csv('35.csv')
aj.to_csv('36.csv')
ak.to_csv('37.csv')
al.to_csv('38.csv')
am.to_csv('39.csv')
an.to_csv('40.csv')
ao.to_csv('41.csv')
ap.to_csv('42.csv')
aq.to_csv('43.csv')

# %%
a1.to_csv('44.csv')
a2.to_csv('45.csv')
a3.to_csv('46.csv')
a4.to_csv('47.csv')
a5.to_csv('48.csv')
a6.to_csv('49.csv')
a7.to_csv('50.csv')
a8.to_csv('51.csv')
a9.to_csv('52.csv')
a10.to_csv('53.csv')
a11.to_csv('54.csv')
a12.to_csv('55.csv')
a13.to_csv('56.csv')
a14.to_csv('57.csv')
a15.to_csv('58.csv')
a16.to_csv('59.csv')
a17.to_csv('60.csv')
a18.to_csv('61.csv')
a19.to_csv('62.csv')
a20.to_csv('63.csv')

a21.to_csv('64.csv')
a22.to_csv('65.csv')
a23.to_csv('66.csv')
a24.to_csv('67.csv')
a25.to_csv('68.csv')
a26.to_csv('69.csv')
a27.to_csv('70.csv')
a28.to_csv('71.csv')
a29.to_csv('72.csv')
a30.to_csv('73.csv')
a31.to_csv('74.csv')
a32.to_csv('75.csv')
a33.to_csv('76.csv')
a34.to_csv('77.csv')
a35.to_csv('78.csv')
a36.to_csv('79.csv')
a37.to_csv('80.csv')
a38.to_csv('81.csv')
a39.to_csv('82.csv')
a40.to_csv('83.csv')
a41.to_csv('84.csv')
a42.to_csv('85.csv')
a43.to_csv('86.csv')
a44.to_csv('87.csv')
a45.to_csv('88.csv')
a46.to_csv('89.csv')
a47.to_csv('90.csv')
a48.to_csv('91.csv')
a49.to_csv('92.csv')
a50.to_csv('93.csv')
a51.to_csv('94.csv')
a52.to_csv('95.csv')
a53.to_csv('96.csv')
a54.to_csv('97.csv')
a55.to_csv('98.csv')



a56.to_csv('99.csv')
a57.to_csv('100.csv')
a58.to_csv('101.csv')
a59.to_csv('102.csv')
a60.to_csv('103.csv')
a61.to_csv('104.csv')
a62.to_csv('105.csv')
a63.to_csv('106.csv')
a64.to_csv('107.csv')
a65.to_csv('108.csv')
a66.to_csv('109.csv')
a67.to_csv('110.csv')
a68.to_csv('111.csv')
a69.to_csv('112.csv')
a70.to_csv('113.csv')
a71.to_csv('114.csv')
a72.to_csv('115.csv')
a73.to_csv('116.csv')
a74.to_csv('117.csv')
a75.to_csv('118.csv')
a76.to_csv('119.csv')
a77.to_csv('120.csv')
a78.to_csv('121.csv')
a79.to_csv('122.csv')
a80.to_csv('123.csv')
a81.to_csv('124.csv')
a82.to_csv('125.csv')
a83.to_csv('126.csv')
a84.to_csv('127.csv')
a85.to_csv('128.csv')
a86.to_csv('129.csv')
a87.to_csv('130.csv')
a88.to_csv('131.csv')
a89.to_csv('132.csv')
a90.to_csv('133.csv')
a91.to_csv('134.csv')
a92.to_csv('135.csv')
a93.to_csv('136.csv')
a94.to_csv('137.csv')
a95.to_csv('138.csv')
a96.to_csv('139.csv')
a97.to_csv('140.csv')
a98.to_csv('141.csv')
a99.to_csv('142.csv')
a100.to_csv('143.csv')


a101.to_csv('144.csv')
a102.to_csv('145.csv')
a103.to_csv('146.csv')
a104.to_csv('147.csv')
a105.to_csv('148.csv')
a106.to_csv('149.csv')
a107.to_csv('150.csv')

a108.to_csv('151.csv')
a109.to_csv('152.csv')
a110.to_csv('153.csv')
a111.to_csv('154.csv')
a112.to_csv('155.csv')
a113.to_csv('156.csv')
a114.to_csv('157.csv')
a115.to_csv('158.csv')
a116.to_csv('159.csv')
a117.to_csv('160.csv')
a118.to_csv('161.csv')
a119.to_csv('162.csv')
a120.to_csv('163.csv')
a121.to_csv('164.csv')
a122.to_csv('165.csv')
a123.to_csv('166.csv')
a124.to_csv('167.csv')
a125.to_csv('168.csv')
a126.to_csv('169.csv')
a127.to_csv('170.csv')
a128.to_csv('171.csv')
a129.to_csv('172.csv')
a130.to_csv('173.csv')


a131.to_csv('174.csv')
a132.to_csv('175.csv')
a134.to_csv('176.csv')
a135.to_csv('177.csv')
a136.to_csv('178.csv')
a137.to_csv('179.csv')
a138.to_csv('180.csv')
a139.to_csv('181.csv')
a140.to_csv('182.csv')
a141.to_csv('183.csv')
a142.to_csv('184.csv')
a143.to_csv('185.csv')
a144.to_csv('186.csv')
a145.to_csv('187.csv')
a146.to_csv('188.csv')
a147.to_csv('189.csv')
a148.to_csv('190.csv')
a149.to_csv('191.csv')
a150.to_csv('192.csv')
a151.to_csv('193.csv')
a152.to_csv('194.csv')
a153.to_csv('195.csv')
a154.to_csv('196.csv')
a155.to_csv('197.csv')
a156.to_csv('198.csv')
a157.to_csv('119.csv')
a158.to_csv('200.csv')
